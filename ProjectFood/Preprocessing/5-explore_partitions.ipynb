# %%
import pandas as pd

# %%
train = pd.read_csv("processed_dataframes/train.csv")
val = pd.read_csv("processed_dataframes/val.csv")
test = pd.read_csv("processed_dataframes/test.csv")

total = pd.read_csv("processed_dataframes/interactions.csv")

# %%
counts = list(total["user_id"].value_counts().to_dict().items())
counts = sorted(counts, key=lambda x: x[1])
print(counts)

user_ids_with_10_or_more = [(user_id, n_interactions) for user_id, n_interactions in counts if n_interactions >= 10]
# Out:
# [(74567, 1), (211710, 1), (124781, 1), (185675, 1), (104076, 1), (21956, 1), (143246, 1), (185979, 1), (13485, 1), (70, 1), (10609, 1), (7487, 1), (154761, 1), (142484, 1), (211671, 1), (3014, 1), (74288, 1), (56566, 1), (59289, 1), (10493, 1), (113678, 1), (35912, 1), (5285, 1), (23841, 1), (28181, 1), (80841, 1), (182239, 1), (178628, 1), (163542, 1), (59060, 1), (57281, 1), (8624, 1), (128633, 1), (55281, 1), (146351, 1), (1836, 1), (51878, 1), (118078, 1), (78726, 1), (49904, 1), (158996, 1), (222588, 1), (138832, 1), (168688, 1), (126281, 1), (225432, 1), (120860, 1), (120266, 1), (45925, 1), (184291, 1), (46318, 1), (54816, 1), (9846, 1), (224008, 1), (46509, 1), (91270, 1), (103914, 1), (88378, 1), (5748, 1), (22760, 1), (185577, 1), (153564, 1), (62010, 1), (143787, 1), (100695, 1), (8901, 1), (162002, 1), (169313, 1), (114319, 1), (53256, 1), (214357, 1), (186038, 1), (45797, 1), (150895, 1), (186872, 1), (180487, 1), (194421, 1), (40412, 1), (160628, 1), (154822, 1), (81945
# ...

# %%
print(user_ids_with_10_or_more)
# Out:
# [(28368, 10), (38567, 10), (75074, 10), (32124, 10), (57051, 10), (56885, 10), (53894, 10), (54258, 10), (12337, 10), (5896, 10), (91465, 10), (18386, 10), (17234, 10), (55426, 10), (74964, 10), (13182, 10), (21439, 10), (70476, 10), (26433, 10), (91001, 10), (102933, 10), (157522, 10), (52129, 10), (45721, 10), (65365, 10), (42504, 10), (89595, 10), (63717, 10), (27418, 10), (19908, 10), (82713, 10), (83405, 10), (44537, 10), (53253, 10), (49940, 10), (21286, 10), (51711, 10), (103409, 10), (31884, 10), (80345, 10), (17541, 10), (24149, 10), (109876, 10), (67732, 10), (71585, 10), (4506, 10), (84798, 10), (2608, 10), (46898, 10), (42489, 10), (7059, 10), (60772, 10), (22746, 10), (85271, 10), (2496, 10), (3424, 10), (59679, 10), (23463, 10), (41668, 10), (21641, 10), (105481, 10), (24220, 10), (43284, 10), (53014, 10), (81660, 10), (147504, 10), (64597, 10), (59534, 10), (4721, 10), (23764, 10), (118378, 10), (107543, 10), (144511, 10), (45641, 10), (11668, 10), (105397, 10), (22914
# ...
